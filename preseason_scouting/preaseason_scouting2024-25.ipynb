# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Load in the scouting df from the ``get_szn_data.ipynb`` output

# %%
szn = '2024-25'
df = pd.read_csv(f'data/scouting/scouting_{szn}.csv')
df.head()
# Out:
#                name prev_position         team   xP    xA    xG  assists  \
# 0  Jack Hinshelwood           MID     Brighton  1.5  0.00  0.00        0
# 1      Jadon Sancho           MID      Man Utd  3.0  0.05  0.00        0
# 2     Vitaly Janelt           MID    Brentford  2.1  0.01  0.02        0
# 3        Ionuț Radu            GK  Bournemouth  2.4  0.00  0.00        0
# 4     Jack Grealish           MID     Man City  4.1  0.00  0.00        0
#
#    goals_scored  bonus  bps  minutes  total_points  prev_price  GW  \
# 0             0      0    0        0             0          45   1
# 1             0      0    4       22             1          70   1
# 2             0      0    6       90             2          55   1
# 3             0      0    0        0             0          45   1
# 4             0      0    0        0             0          75   1
#
#    current_price current_position
# 0           50.0              MID
# 1           65.0              MID
# 2           50.0              MID
# 3            NaN              DEF
# 4           65.0              MID

# %% [markdown]
# ## Select a gamweek window (optional)
#
# Let's select only the last half of the season, as that may be more indicative for current player performance.
#
# This collapses the the data across all selected GWs!

# %%
def select_gw_subset(df, gw_start, gw_end):
    '''
    Function to select a subset of the FDR dataframe based on the gameweeks and teams you want to look at.
    
    Parameters:
    - df: merged GW DataFrame - each row is the stats for a player in a given GW.
    - gw_start: The starting gameweek (inclusive).
    - gw_end: The ending gameweek (inclusive).
    
    Returns:
    - A DataFrame subset based on the specified gameweeks.
    '''
    gws = np.arange(gw_start,gw_end+1)
    df = df[df['GW'].isin(gws)].reset_index(drop=True)
    df = df.drop(columns=['GW'])

    df = df.dropna()


    df = df.groupby(by=['name', 'current_position', 'team'], as_index=False).agg(xP={'xP':'sum'},
                                                            xA=('xA', 'sum'),
                                                            xG=('xG','sum'),
                                                            A=('assists', 'sum'),
                                                            G=('goals_scored', 'sum'),
                                                            mins=('minutes', 'sum'),
                                                            total_points=('total_points', 'sum'),
                                                            bonus=('bonus','sum'),
                                                            prev_price=('prev_price', 'mean'),
                                                            current_price=('current_price', 'mean'))


    # players['value'] = players['value'].round(0).astype(int)
    # players
    
    return df

# %%
df_subset = select_gw_subset(df, 19, 38)
df_subset.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df_subset = select_gw_subset(df, 19, 38)
#       2 df_subset.head()
#
# Cell In[62], line 20, in select_gw_subset(df, gw_start, gw_end)
#      15 df = df.drop(columns=['GW'])
#      17 df = df.dropna()
# ---> 20 df = df.groupby(by=['name', 'current_position', 'team'], as_index=False).agg(xP={'xP':'sum'},
#      21                                                         xA=('xA', 'sum'),
#      22                                                         xG=('xG','sum'),
#      23                                                         A=('assists', 'sum'),
#      24                                                         G=('goals_scored', 'sum'),
#      25                                                         mins=('minutes', 'sum'),
#      26                                                         total_points=('total_points', 'sum'),
#      27                                                         bonus=('bonus','sum'),
#      28                                                         prev_price=('prev_price', 'mean'),
#      29                                                         current_price=('current_price', 'mean'))
#      32 # players['value'] = players['value'].round(0).astype(int)
#      33 # players
#      35 return df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1435, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1433 @doc(_agg_template_frame, examples=_agg_examples_doc, klass="DataFrame")
#    1434 def aggregate(self, func=None, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1435     relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    1436     func = maybe_mangle_lambdas(func)
#    1438     if maybe_use_numba(engine):
#    1439         # Not all agg functions support numba, only propagate numba kwargs
#    1440         # if user asks for numba
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1478, in reconstruct_func(func, **kwargs)
#    1472         raise SpecificationError(
#    1473             "Function names must be unique if there is no new column names "
#    1474             "assigned"
#    1475         )
#    1476     if func is None:
#    1477         # nicer error message
# -> 1478         raise TypeError("Must provide 'func' or tuples of '(column, aggfunc).")
#    1480 if relabeling:
#    1481     func, columns, order = normalize_keyword_aggregation(kwargs)
#
# TypeError: Must provide 'func' or tuples of '(column, aggfunc).

# %% [markdown]
# ## Points per 90, per $

# %% [markdown]
# Let's add some informative columns

# %%
# points per minute
df_subset['ppm'] = df_subset['points'] / df_subset['mins']

# number of 90s (full matches) they played
df_subset['90s'] = df_subset['mins'] / 90

#
df_subset['ppg'] = df_subset['points'] / df_subset['90s']

# %% [markdown]
# ## Overperforming and underperforming players (Watkins)

# %% [markdown]
# # OLD

# %% [markdown]
# ### Create a players df

# %%
players = df.groupby(by=['name', 'position', 'team'], as_index=False).agg(xa=('expected_assists', 'sum'),
                                                              A=('assists', 'sum'),
                                                              xg=('expected_goals','sum'),
                                                              G=('goals_scored', 'sum'),
                                                              mins=('minutes', 'sum'),
                                                              points=('total_points', 'sum'),
                                                              bonus=('bonus','sum'),
                                                              value=('value', 'mean'))
                                                             
players['value'] = players['value'].round(0).astype(int)
players
# Out:
#                            name position       team       xa  A      xg  G  \
# 0               Aaron Cresswell      DEF   West Ham  1.09260  1  0.1433  0
# 1                  Aaron Hickey      DEF  Brentford  0.46000  3  0.3100  0
# 2                Aaron Ramsdale       GK    Arsenal  0.01619  0  0.0000  0
# 3             Aaron Wan-Bissaka      DEF    Man Utd  0.91981  0  1.1857  0
# 4            Abdoulaye Doucouré      MID    Everton  1.46968  2  2.4918  5
# ..                          ...      ...        ...      ... ..     ... ..
# 680  Yerson Mosquera Valdelamar      DEF     Wolves  0.00000  0  0.0000  0
# 681                 Yoane Wissa      MID  Brentford  0.93299  4  3.0141  7
# 682               Yves Bissouma      MID      Spurs  0.19400  0  0.0528  0
# 683                Zack Steffen       GK   Man City  0.00000  0  0.0000  0
# 684                Zidane Iqbal      MID    Man Utd  0.00000  0  0.0000  0
#
#      mins  points  bonus  value
# 0    2235      74      8     48
# 1    1918      63      2     49
# 2    3420     143      9     49
# 3    1432      67      3     43
# 4    1527      76     10     53
# ..    ...     ...    ...    ...
# 680     0       0      0     39
# 681  1587     111      6     53
# 682   998      27      0     47
# 683     0       0      0     40
# 684     0       0      0     43
#
# [685 rows x 11 columns]

# %%
#drop those who played less than 350 mins
# players = players[players['mins'] > 350]
# players

# %%
#sort values by total points 
players = players.sort_values(by=['points'], ascending=False)
players = players.reset_index()
players = players.drop(columns='index')
players
# Out:
#                     name position       team       xa   A       xg   G  mins  \
# 0         Erling Haaland      FWD   Man City  1.33591   9  17.4943  36  2767
# 1             Harry Kane      FWD      Spurs  2.72175   9  12.0402  30  3406
# 2          Mohamed Salah      MID  Liverpool  4.69210  13  14.7355  19  3290
# 3        Martin Ødegaard      MID    Arsenal  5.11981   8   6.7737  15  3132
# 4        Marcus Rashford      MID    Man Utd  1.59559   7  11.4763  17  2880
# ..                   ...      ...        ...      ...  ..      ...  ..   ...
# 680  Nuno Varela Tavares      DEF    Arsenal  0.00000   0   0.0000   0     0
# 681   Ishé Samuels-Smith      DEF    Everton  0.00000   0   0.0000   0     0
# 682          Isaac Price      MID    Everton  0.01821   0   0.0000   0    32
# 683        Imari Samuels      DEF   Brighton  0.00000   0   0.0000   0     0
# 684         Zidane Iqbal      MID    Man Utd  0.00000   0   0.0000   0     0
#
#      points  bonus  value
# 0       272     40    121
# 1       263     48    116
# 2       239     23    129
# 3       212     30     67
# 4       205     21     69
# ..      ...    ...    ...
# 680       0      0     45
# 681       0      0     40
# 682       0      0     45
# 683       0      0     40
# 684       0      0     43
#
# [685 rows x 11 columns]

# %%
#Get names and prices of 2023 season
position_mapping = {
        1: "GK",
        2: "DEF",
        3: "MID",
        4: "FWD"
    }
# Send a GET request to the FPL website
url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
response = requests.get(url)
data = response.json()

# Extract player information from the response
all_players = data['elements']

# Iterate over each player and print their name and price
names_2023 = []
positions_2023 = []
prices_2023 = []

for player in all_players:
    fname = player['first_name']
    lname = player['second_name']
    name = fname+' '+lname
    #get price at the start of the 2023 season
    price = (player['now_cost'] - player['cost_change_start']) / 10  # Divide by 10 to get the actual price
    #get 2023 position
    element_type = player['element_type']
    position = position_mapping[element_type]
    #append to lists
    positions_2023.append(position)
    names_2023.append(name)
    prices_2023.append(price)

# %%
#get names in both 2022 and 2023 szn
names_2022 = players['name'].unique()

ns = []
poss = []
ps = []

for i in range(len(names_2023)):
    if names_2023[i] in names_2022:
        ns.append(names_2023[i])
        poss.append(positions_2023[i])
        ps.append(prices_2023[i])
        
#name and price, and name and position mappings
name_price = dict(zip(ns, ps))
name_pos = dict(zip(ns, poss))

# %%
#get price from 2023 game
players['2023_price'] = [''] * players.shape[0]
players['position'] = [''] * players.shape[0]

for i in range(players.shape[0]):
    name = players['name'].iloc[i]
    try:
        price = name_price[name]
    except:
        price = ''
    try:
        position = name_pos[name]
    except:
        position = ''
    #players['2023_price'].iloc[i] = price
    players.loc[i, '2023_price'] = price
    players.loc[i, 'position'] = position
players = players.drop(columns='value')
players['ppm'] = players['points'] / players['mins']
players['90s'] = players['mins'] / 90
players['ppg'] = players['points'] / players['90s']
players.head(20)
# Out:
#                         name position            team       xa   A       xg  \
# 0             Erling Haaland      FWD        Man City  1.33591   9  17.4943
# 1                 Harry Kane      FWD           Spurs  2.72175   9  12.0402
# 2              Mohamed Salah      MID       Liverpool  4.69210  13  14.7355
# 582                     Matthew Cox       GK       Brentford  0.00000  0  0.0
# 595                  Mark Gillespie       GK       Newcastle  0.00000  0  0.0
# 598                    Loris Karius       GK       Newcastle  0.00000  0  0.0
# 611                     Karl Darlow       GK       Newcastle  0.00000  0  0.0
# 618                  Kjell Scherpen       GK        Brighton  0.00000  0  0.0
# 619               Marcus Bettinelli       GK         Chelsea  0.00000  0  0.0
# 623                       Karl Hein       GK         Arsenal  0.00000  0  0.0
# 640                  George Shelvey       GK   Nott'm Forest  0.00000  0  0.0
# 641                    Oliwier Zych       GK     Aston Villa  0.00000  0  0.0
# 646                 Filip Marschall       GK     Aston Villa  0.00000  0  0.0
# 649                   Remi Matthews       GK  Crystal Palace  0.00000  0  0.0
# 658                    James Wright       GK     Aston Villa  0.00000  0  0.0
#
#      G  mins  points  bonus 2023_price       ppm        90s       ppg
# 32   0  3240     142     17        4.5  0.043827  36.000000  3.944444
# 48   0  3111     127     10        4.5  0.040823  34.566667  3.674060
# 55   0  3330     124     10        4.5  0.037237  37.000000  3.351351
# 98   0  2430      99     10        4.5  0.040741  27.000000  3.666667
# 112  0  2385      93      9        4.5  0.038994  26.500000  3.509434
# 137  0  1620      82     12        4.5  0.050617  18.000000  4.555556
# 139  0  2070      82     10        4.5  0.039614  23.000000  3.565217
# 185  0  1350      65      8        4.5  0.048148  15.000000  4.333333
# 266  0  1215      40      1        4.0  0.032922  13.500000  2.962963
# 281  0   810      36      5        4.5  0.044444   9.000000  4.000000
# 312  0  1035      28      1        4.0  0.027053  11.500000  2.434783
# 335  0   270      23      5        4.0  0.085185   3.000000  7.666667
# 382  0   156      11      1        4.0  0.070513   1.733333  6.346154
# 383  0   280      10      1        4.0  0.035714   3.111111  3.214286
# 392  0   271       8      0        4.0  0.029520   3.011111  2.656827
# 393  0   307       7      0        4.0  0.022801   3.411111  2.052117
# 399  0   180       7      0        4.0  0.038889   2.000000  3.500000
# 406  0   180       6      0        4.0  0.033333   2.000000  3.000000
# 446  0    90       2      0        4.0  0.022222   1.000000  2.000000
# 480  0     0       0      0        4.0       NaN   0.000000       NaN
# 484  0     0       0      0        4.0       NaN   0.000000       NaN
# 486  0     0       0      0        4.0       NaN   0.000000       NaN
# 499  0     0       0      0        4.0       NaN   0.000000       NaN
# 501  0     0       0      0        4.0       NaN   0.000000       NaN
# 504  0     0       0      0        4.0       NaN   0.000000       NaN
# 518  0     0       0      0        4.0       NaN   0.000000       NaN
# 527  0     0       0      0        4.0       NaN   0.000000       NaN
# 528  0     0       0      0        4.0       NaN   0.000000       NaN
# 538  0     0       0      0        4.0       NaN   0.000000       NaN
# 539  0     0       0      0        4.0       NaN   0.000000       NaN
# 548  0     0       0      0        4.0       NaN   0.000000       NaN
# 568  0     0       0      0        4.0       NaN   0.000000       NaN
# 576  0     0       0      0        4.0       NaN   0.000000       NaN
# 577  0     0       0      0        4.0       NaN   0.000000       NaN
# 580  0     0       0      0        4.0       NaN   0.000000       NaN
# 582  0     0       0      0        4.0       NaN   0.000000       NaN
# 595  0     0       0      0        4.0       NaN   0.000000       NaN
# 598  0     0       0      0        4.0       NaN   0.000000       NaN
# 611  0     0       0      0        4.0       NaN   0.000000       NaN
# 618  0     0       0      0        4.0       NaN   0.000000       NaN
# 619  0     0       0      0        4.0       NaN   0.000000       NaN
# 623  0     0       0      0        4.0       NaN   0.000000       NaN
# 640  0     0       0      0        4.0       NaN   0.000000       NaN
# 641  0     0       0      0        4.0       NaN   0.000000       NaN
# 646  0     0       0      0        4.0       NaN   0.000000       NaN
# 649  0     0       0      0        4.0       NaN   0.000000       NaN
# 658  0     0       0      0        4.0       NaN   0.000000       NaN

# %% [markdown]
# ## Top Defenders

# %%
defs = players[players['position'] == 'DEF']
defs.head(20)
# Out:
#                             name position         team       xa   A      xg  \
# 7                Kieran Trippier      DEF    Newcastle  7.73913   9  0.4675
# 20        Trent Alexander-Arnold      DEF    Liverpool  7.02897  11  1.3384
# 21                Benjamin White      DEF      Arsenal  2.81544   5  0.9776
# 27  Gabriel dos Santos Magalhães      DEF      Arsenal  0.47026   0  2.8539
# 30                       Ben Mee      DEF    Brentford  0.38631   2  1.9479
# 36                  Fabian Schär      DEF    Newcastle  1.25849   3  3.7244
# 44                  Tyrone Mings      DEF  Aston Villa  0.40507   3  0.9400
# 45                   Sven Botman      DEF    Newcastle  0.18437   2  2.4064
# 46                      Dan Burn      DEF    Newcastle  1.14651   0  1.7445
# 47              Pervis Estupiñán      DEF     Brighton  2.51978   7  1.6653
# 49               Virgil van Dijk      DEF    Liverpool  0.68162   1  1.7084
# 56                     Luke Shaw      DEF      Man Utd  2.19548   4  0.9230
# 62              Andrew Robertson      DEF    Liverpool  4.66957   8  0.8600
# 67                William Saliba      DEF      Arsenal  0.17966   1  0.5633
# 71                 Ethan Pinnock      DEF    Brentford  0.79166   0  2.5990
# 72                    Lewis Dunk      DEF     Brighton  0.75646   1  0.9649
# 73                    Rico Henry      DEF    Brentford  2.08715   3  1.2500
# 75              Ezri Konsa Ngoyo      DEF  Aston Villa  0.33942   0  0.6200
# 76                    Max Kilman      DEF       Wolves  0.37772   1  0.7375
# 81               James Tarkowski      DEF      Everton  1.48245   1  2.2190
#
#     G  mins  points  bonus 2023_price       ppm        90s       ppg
# 7   1  3342     198     39        6.5  0.059246  37.133333  5.332136
# 20  2  2922     156     21        8.0  0.053388  32.466667  4.804928
# 21  2  3054     156     12        5.5  0.051081  33.933333  4.597250
# 27  3  3409     146     15        5.0  0.042828  37.877778  3.854503
# 30  3  3269     143     11        5.0  0.043744  36.322222  3.936984
# 36  1  3207     139      6        5.0  0.043343  35.633333  3.900842
# 44  1  3150     130     17        4.5  0.041270  35.000000  3.714286
# 45  0  3127     129      8        4.5  0.041254  34.744444  3.712824
# 46  1  3109     129      6        4.5  0.041492  34.544444  3.734320
# 47  1  2674     128     15        5.0  0.047868  29.711111  4.308153
# 49  3  2835     127     13        6.0  0.044797  31.500000  4.031746
# 56  1  2552     124     20        5.5  0.048589  28.355556  4.373041
# 62  0  2579     121     10        6.5  0.046917  28.655556  4.222567
# 67  2  2415     117     14        5.0  0.048447  26.833333  4.360248
# 71  3  2700     112      6        4.5  0.041481  30.000000  3.733333
# 72  1  3240     112      7        5.0  0.034568  36.000000  3.111111
# 73  0  3240     112      4        4.5  0.034568  36.000000  3.111111
# 75  0  3322     110      6        4.5  0.033113  36.911111  2.980132
# 76  0  3307     109     12        4.5  0.032960  36.744444  2.966435
# 81  1  3420     106     13        4.5  0.030994  38.000000  2.789474

# %%
defs[defs['team'] == 'Man City']
# Out:
#                       name position      team       xa  A      xg  G  mins  \
# 111            John Stones      DEF  Man City  0.27697  2  0.7877  2  1844
# 115             Nathan Aké      DEF  Man City  0.99391  0  1.4433  1  1871
# 134          Manuel Akanji      DEF  Man City  0.86633  1  0.6545  0  2284
# 142  Rúben Gato Alves Dias      DEF  Man City  0.22000  0  0.7500  0  1997
# 162           João Cancelo      DEF  Man City  0.48951  2  0.3074  2  1273
# 172            Kyle Walker      DEF  Man City  1.09699  0  0.0743  0  1953
# 260        Aymeric Laporte      DEF  Man City  0.36248  0  0.3845  0   992
# 304             Rico Lewis      DEF  Man City  1.61457  0  0.2094  0   900
# 342           Sergio Gómez      DEF  Man City  0.86000  1  0.2300  0   340
#
#      points  bonus 2023_price       ppm        90s       ppg
# 111      93     13        5.5  0.050434  20.488889  4.539046
# 115      92      9        5.0  0.049172  20.788889  4.425441
# 134      82      5        5.0  0.035902  25.377778  3.231173
# 142      80      1        5.5  0.040060  22.188889  3.605408
# 162      73     10        6.0  0.057345  14.144444  5.161037
# 172      69      0        5.0  0.035330  21.700000  3.179724
# 260      40      3        5.0  0.040323  11.022222  3.629032
# 304      29      0        4.5  0.032222  10.000000  2.900000
# 342      21      1        4.0  0.061765   3.777778  5.558824

# %% [markdown]
# ## Top Midfielders

# %%
mid = players[players['position'] == 'MID']
mid.head(20)
# Out:
#                             name position            team       xa   A  \
# 2                  Mohamed Salah      MID       Liverpool  4.69210  13
# 3                Martin Ødegaard      MID         Arsenal  5.11981   8
# 4                Marcus Rashford      MID         Man Utd  1.59559   7
# 5                    Bukayo Saka      MID         Arsenal  4.19346  12
# 6       Gabriel Martinelli Silva      MID         Arsenal  4.22851   9
# 8                Kevin De Bruyne      MID        Man City  7.41061  18
# 10        Bruno Borges Fernandes      MID         Man Utd  8.00037   9
# 15                   Pascal Groß      MID        Brighton  6.32062   8
# 16                  Eberechi Eze      MID  Crystal Palace  1.57310   5
# 17         Miguel Almirón Rejala      MID       Newcastle  1.86317   4
# 22                  Granit Xhaka      MID         Arsenal  2.41220   8
# 23                 Son Heung-min      MID           Spurs  2.73276   6
# 24                  Bryan Mbeumo      MID       Brentford  3.88866   9
# 26                   Solly March      MID        Brighton  4.49333  10
# 28                  Jarrod Bowen      MID        West Ham  4.65935   9
# 31  Douglas Luiz Soares de Paulo      MID     Aston Villa  2.22645   7
# 33                    Phil Foden      MID        Man City  2.86822   7
# 34            Morgan Gibbs-White      MID   Nott'm Forest  4.02234  12
